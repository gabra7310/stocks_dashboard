# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import yfinance as yf

from datetime import datetime
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_4380\358723060.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #

# %%
end_data = datetime.now().strftime('%Y-%m-%d')

# %%
tickers = ['VALE3.SA', 'PETR4.SA']

# %%
data_vale = yf.download(tickers, start="2017-01-01", end=end_data, progress=False)
data_vale = data_vale.reset_index()
# Out:
# c:\ProgramData\Anaconda3\envs\stocks_dash\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\ProgramData\Anaconda3\envs\stocks_dash\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
data_vale['Adj Close']
# Out:
# Ticker   PETR4.SA   VALE3.SA
# 0        5.005718  15.730232
# 1        5.292541  16.426983
# 2        5.292541  16.131958
# 3        5.377903  16.747114
# 4        5.347173  16.301441
# ...           ...        ...
# 1754    37.529999  68.099998
# 1755    37.700001  67.800003
# 1756    38.169998  69.199997
# 1757    37.880001  69.900002
# 1758    39.279999  68.180000
#
# [1759 rows x 2 columns]

# %%
data_vale
# Out:
# Price        Date  Adj Close                 Close                  High  \
# Ticker              PETR4.SA   VALE3.SA   PETR4.SA   VALE3.SA   PETR4.SA
# 0      2017-01-02   5.005718  15.730232  14.660000  25.059999  14.700000
# 1      2017-01-03   5.292541  16.426983  15.500000  26.170000  15.650000
# 2      2017-01-04   5.292541  16.131958  15.500000  25.700001  15.680000
# 3      2017-01-05   5.377903  16.747114  15.750000  26.680000  15.910000
# 4      2017-01-06   5.347173  16.301441  15.660000  25.969999  15.920000
# ...           ...        ...        ...        ...        ...        ...
# 1754   2024-01-19  37.529999  68.099998  37.529999  68.099998  37.900002
# 1755   2024-01-22  37.700001  67.800003  37.700001  67.800003  37.810001
# 1756   2024-01-23  38.169998  69.199997  38.169998  69.199997  38.369999
# 1757   2024-01-24  37.880001  69.900002  37.880001  69.900002  38.540001
# 1758   2024-01-25  39.279999  68.180000  39.279999  68.180000  39.279999
#
# ...
